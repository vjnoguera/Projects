# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as py
import plotly.graph_objects as go
from wordcloud import WordCloud

# %%
df1 = pd.read_csv(r"C:\Users\Victor\Desktop\EDA\CSV\scimagojr country rank 1996-2023.csv", encoding="latin-1")
df1
# Out:
#      Rank                            Country            Region  Documents  \
# 0       1                      United States  Northern America   16047770
# 1       2                              China    Asiatic Region   10372322
# 2       3                     United Kingdom    Western Europe    4778980
# 3       4                            Germany    Western Europe    4104599
# 4       5                              Japan    Asiatic Region    3482279
# ..    ...                                ...               ...        ...
# 238   239                   Christmas Island    Pacific Region          7
# 239   240          Saint Pierre and Miquelon  Northern America          7
# 240   241        French Southern Territories    Pacific Region          6
# 241   242                           Pitcairn    Pacific Region          3
# 242   243  Heard Island and McDonald Islands    Pacific Region          2
#
#      Citable documents  Citations  Self-citations Citations per document  \
# ...

# %%
df1.loc[df1.loc[:,"Documents"].sort_values(ascending=False).index][0:10]
# Out:
#    Rank         Country            Region  Documents  Citable documents  \
# 0     1   United States  Northern America   16047770           13969135
# 1     2           China    Asiatic Region   10372322           10180089
# 2     3  United Kingdom    Western Europe    4778980            3984194
# 3     4         Germany    Western Europe    4104599            3741033
# 4     5           Japan    Asiatic Region    3482279            3308467
# 5     6           India    Asiatic Region    2970196            2700702
# 6     7          France    Western Europe    2784321            2561817
# 7     8           Italy    Western Europe    2525870            2269098
# 8     9          Canada  Northern America    2426840            2156112
# 9    10       Australia    Pacific Region    2009795            1756807
#
#    Citations  Self-citations Citations per document  H index
# 0  515339352       211154763                  32,11     3051
# ...

# %%
# Dividir los valores por 1,000,000 para mostrar en millones
df1["Documents_millions"] = df1["Documents"] / 1000000

# Crear el gráfico de barras
plt.figure(figsize=(15,8))  # Tamaño ajustado

# Colores progresivos de rojo a azul
colors = sns.color_palette("RdYlBu",18)
# colors = sns.color_palette("flare", as_cmap=True)

barplot = sns.barplot(x=df1["Country"][0:10],
                      y=df1["Documents_millions"][0:10],
                      palette=colors)

# Añadir etiquetas en la parte superior de cada columna
for index, value in enumerate(df1["Documents"][0:10]):
    barplot.text(index, value/1000000, str(value), ha='center', fontsize=12, va='bottom')  # Dividir por 1,000,000 para mostrar en millones

# Ajustar el tamaño y la inclinación del texto del eje x y y
plt.xticks(rotation=45, ha='right', fontsize=16)
plt.yticks(fontsize=16)

# Etiquetas del eje x y y
plt.xlabel("Country", fontsize=16)
plt.ylabel("Papers (Millions)", fontsize=16)  # Cambiar la etiqueta del eje Y

# Título
plt.title("Top 10 total publications per Country 1996-2023", fontsize=14)

plt.tight_layout()  # Ajuste automático de diseño
plt.show()
# Out:
# C:\Users\Victor\AppData\Local\Temp\ipykernel_28312\1940067778.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(x=df1["Country"][0:10],
# C:\Users\Victor\AppData\Local\Temp\ipykernel_28312\1940067778.py:14: UserWarning: The palette list has more values (18) than needed (10), which may not be intended.
#   barplot = sns.barplot(x=df1["Country"][0:10],

# %%
unis = df1["Country"][0:10].to_list()

# %%
uxc = [3180,2495,337,461,992,5349,625,289,383,387]

# %%
# Dividir los valores por 1,000,000 para mostrar en millones
df1["Documents_millions"] = df1["Documents"] / 1000000

# Crear el gráfico de barras
plt.figure(figsize=(15,8))  # Tamaño ajustado

# Colores progresivos de rojo a azul
colors = sns.color_palette("RdYlBu",18)
# colors = sns.color_palette("flare", as_cmap=True)

barplot = sns.barplot(x=df1["Country"][0:10],
                      y=df1["Documents_millions"][0:10],
                      palette=colors)

# Añadir etiquetas en la parte superior de cada columna
for index, value in enumerate(df1["Documents"][0:10]):
    barplot.text(index, value/1000000, str(value), ha='center', fontsize=12, va='bottom')  # Dividir por 1,000,000 para mostrar en millones

for index, value in enumerate(df1["Country"].value_counts().head(10)):
    # Añadir valor de uxc dentro de cada barra
    barplot.text(index, value/2, str(uxc[index]), ha='center', fontsize=12, color='black')

# Ajustar el tamaño y la inclinación del texto del eje x y y
plt.xticks(rotation=45, ha='right', fontsize=16)
plt.yticks(fontsize=16)

# Etiquetas del eje x y y
plt.xlabel("País", fontsize=16)
plt.ylabel("Publicaciones (Millones)", fontsize=16)  # Cambiar la etiqueta del eje Y

# Título
plt.title("Top 10 publicaciones totales por país 1996-2023", fontsize=14)

plt.tight_layout()  # Ajuste automático de diseño
plt.show()
# Out:
# C:\Users\Victor\AppData\Local\Temp\ipykernel_28312\3750053745.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(x=df1["Country"][0:10],
# C:\Users\Victor\AppData\Local\Temp\ipykernel_28312\3750053745.py:14: UserWarning: The palette list has more values (18) than needed (10), which may not be intended.
#   barplot = sns.barplot(x=df1["Country"][0:10],

# %%
uxc = [3216,2565,280,459,1003,5288,617,239,387,190]

# %%
uxc3y = [3180,337,102,129,461,2495,5349,625,992,1264]
